# %%
import matplotlib.pyplot as plt
from pycocotools.coco import COCO
import cv2
import numpy as np
import os
import json
import datetime

# %%
# Train / Test mode for data loading 
mode = "train"

# Defining images directory
img_dir = f"ChestXDet/{mode}_data/{mode}"

# Loading the respective JSON file for creating the data in COCO segmentation format
dataset_json = open(f"ChestXDet/ChestXDet_Metainformations/ChestX-Det-Dataset-main/ChestX_Det_{mode}.json")
dataset = json.load(dataset_json)

categories = {'Background' : 0 , 'Atelectasis' : 1, 'Calcification'  : 2, 
              'Cardiomegaly': 3, 'Consolidation': 4, 
              'Diffuse Nodule' : 5, 'Effusion' : 6, 
              'Emphysema' : 7, 'Fibrosis' : 8, 
              'Fracture' : 9, 'Mass' : 10, 'Nodule':11, 
              'Pleural Thickening' : 12, 'Pneumothorax' : 13 }


def create_coco_data(img_dir , dataset_json):

    # Create an empty list to store the annotations
    annotations = []
    count = 0

    # Iterate over the images in the dataset
    for i,anno in enumerate(dataset_json):
        
        # Load the image
        image_path = os.path.join(img_dir, anno['file_name'])
        img = cv2.imread(image_path)
        
        # Extract the width and height of the image
        #height, width, _ = img.shape
        height = 1024
        width = 1024
        
        if anno['syms'] == None:
            count += 1
            annotation = {
                "id": count ,  # Use a unique identifier for the annotation
                "image_id": anno['file_name'],  # Use the same identifier for the image
                "category_id": 0,  # Assign a category ID to the object
                "bbox": [0 , 0 , 0 , 0],  # Specify the bounding box in the format [x, y, width, height]
                "area": width * height,  # Calculate the area of the bounding box
                "iscrowd": 0,  # Set iscrowd to 0 to indicate that the object is not part of a crowd
                "segmentation": [],
            }
            annotations.append(annotation)

        # Annotate the image with a bounding box and label
        for j , classes in enumerate(anno['syms']):
            
            bbox = anno['boxes'][j]
            poly = np.array(anno['polygons'][j]).ravel().tolist()

            count += 1
            annotation = {
                "id": count ,  # Use a unique identifier for the annotation
                "image_id": int(anno['file_name'].split(".")[0]),  # Use the same identifier for the image
                "category_id": categories[classes],  # Assign a category ID to the object
                "bbox": [bbox[0], bbox[1], bbox[2] - bbox[0], bbox[3] - bbox[1]],  # Specify the bounding box in the format [x, y, width, height]
                "area": (bbox[2] - bbox[0]) * (bbox[3] - bbox[1]),  # Calculate the area of the bounding box
                "iscrowd": 0,  # Set iscrowd to 0 to indicate that the object is not part of a crowd
                "segmentation": [poly],
            }
            annotations.append(annotation)

    # Create the COCO JSON object
    coco_data = {
        "info": {
            "description": f"ChestX-Det-{mode}",  # Add a description for the dataset
            "url": "N/A",  # Add a URL for the dataset (optional)
            "version": "1.0",  # Set the version of the dataset
            "year": 2023,  # Set the year the dataset was created
            "contributor": "Rahul Pushparajan",  # Add the name of the contributor (optional)
            "date_created": f"{datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S') }",  # Set the date the dataset was created
        },
        "licenses": [],  # Add a list of licenses for the images in the dataset (optional)
        "images": [
            {
                "id": int(image_name.split(".")[0]),  # Use the same identifier as the annotation
                "width": width,  # Set the width of the image
                "height": height,  # Set the height of the image
                "file_name": image_name,  # Set the file name of the image
                "license": "N/A",  # Set the license for the image (optional)
            }
            for i, image_name in enumerate(os.listdir(img_dir))
        ],
        "annotations": annotations,  # Add the list of annotations to the JSON object
        "categories": [
                    { "supercategory": "No disease" , "id" : 0 , "name" : "Background"},
                    {"supercategory": "disease" , "id" : 1 , "name" : "Atelectasis"}, 
                    {"supercategory": "disease" , "id" : 2 , "name" : "Calcification"}, 
                    {"supercategory": "disease" , "id" : 3 , "name" : "Cardiomegaly"},
                    {"supercategory": "disease" , "id" : 4 , "name" : "Consolidation"},
                    {"supercategory": "disease" , "id" : 5 , "name" : "Diffuse Nodule"},  
                    {"supercategory": "disease" , "id" : 6 , "name" : "Effusion"},
                    {"supercategory": "disease" , "id" : 7 , "name" : "Emphysema"},
                    {"supercategory": "disease" , "id" : 8 , "name" : "Fibrosis"},
                    {"supercategory": "disease" , "id" : 9 , "name" : "Fracture"},
                    {"supercategory": "disease" , "id" : 10 , "name" : "Mass"},
                    {"supercategory": "disease" , "id" : 11 , "name" : "Nodule"},
                    {"supercategory": "disease" , "id" : 12 , "name" : "Pleural Thickening"},
                    {"supercategory": "disease" , "id" : 13 , "name" : "Pneumothorax"},
                    ]
                    # Add a list of categories for the objects in the dataset
    }

    return coco_data

# Create the COCO format data
coco_data = create_coco_data(img_dir , dataset)

# Save the COCO JSON object to a file
with open(f"coco_{mode}.json", "w") as f:
    json.dump(coco_data, f)

print(f"File coco_{mode}.json created successfully")
# Out:
# libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# File coco_train.json created successfully

# %%
# Loading the COCO segmentation format JSON file
mode = "train"
coco = COCO(f"coco_{mode}.json")

# Defining the mask and the images directory
mask_dir = f"ChestXDet/{mode}_data/mask"
img_dir = f"ChestXDet/{mode}_data/{mode}"

# Returns the Class Name 
def getClassName(classID, cats):
    for i in range(len(cats)):
        if cats[i]['id']==classID:
            return cats[i]['name']
    return "None"

# Get the category ID 
cat_ids = coco.getCatIds()

# Load the respective categories
cats = coco.loadCats(cat_ids)
classes = [x['name'] for x in cats]

# Create masks for all the images from the given annotation file 
for j, image_name in enumerate(os.listdir(img_dir)):
    img = coco.imgs[int(image_name.split(".")[0])]
    mask = np.zeros((img['height'],img['width']))
    cat_ids = coco.getCatIds()
    anns_ids = coco.getAnnIds(imgIds=img['id'], catIds=cat_ids, iscrowd=None)
    anns = coco.loadAnns(anns_ids)
    
    for ann in anns:
        mask = np.maximum( mask , coco.annToMask( ann )* ann['category_id'] )
    
    mask = mask.astype(np.uint8)
    
    cv2.imwrite(mask_dir + "/" +f"{image_name}" , mask)
    image = cv2.imread(mask_dir + "/" +f"{image_name}" , cv2.IMREAD_GRAYSCALE)
    
    print(f"Unique pixel values in the {image_name} mask are: {np.unique(mask)}" )

print("All Masks created successfully ")
# Out:
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# Unique pixel values in the 69478.png mask are: [0]
# Unique pixel values in the 45199.png mask are: [0]
# Unique pixel values in the 39076.png mask are: [0 6]
# Unique pixel values in the 69433.png mask are: [ 0  5 10]
# Unique pixel values in the 46350.png mask are: [0 4 6 8]
# Unique pixel values in the 40848.png mask are: [0 3 6 9]
# Unique pixel values in the 69516.png mask are: [ 0  1  4  6 13]
# Unique pixel values in the 69460.png mask are: [ 0  3 12]
# Unique pixel values in the 45648.png mask are: [ 0  4  6  8 13]
# Unique pixel values in the 45661.png mask are: [0 4 6]
# Unique pixel values in the 59422.png mask are: [0 6 9]
# Unique pixel values in the 69937.png mask are: [ 0  6  8  9 13]
# Unique pixel values in the 41081.png mask are: [0 3]
# Unique pixel values in the 70491.png mask are: [0 3]
# Unique pixel values in the 60248.png mask are: [ 0 11]
# Unique pixel values in the 57529.png mask are: [ 0  7  8 12]
# Unique pixel values in the 40464.png mask are: [0]
# Unique pixel values in the 39983.png mask are: [0 4]
# Unique pixel values in the 59447.png mask are: [0]
# Unique pixel values in the 57621.png mask are: [0 4 6]
# Unique pixel values in the 40003.png mask are: [0 3]
# Unique pixel values in the 45806.png mask are: [0 4]
# Unique pixel values in the 41156.png mask are: [0 7 8]
# Unique pixel values in the 36364.png mask are: [0]
# Unique pixel values in the 39462.png mask are: [0 3]
# Unique pixel values in the 70439.png mask are: [0 6]
# Unique pixel values in the 41175.png mask are: [0 8]
# Unique pixel values in the 47297.png mask are: [0 4]
# Unique pixel values in the 40459.png mask are: [0]
# Unique pixel values in the 41816.png mask are: [0 3 6]
# Unique pixel values in the 69110.png mask are: [0 8]
# Unique pixel values in the 59584.png mask are: [0 2]
# Unique pixel values in the 69034.png mask are: [0]
# Unique pixel values in the 45290.png mask are: [0]
# Unique pixel values in the 62125.png mask are: [0 4 6]
# Unique pixel values in the 59062.png mask are: [0 8]
# Unique pixel values in the 70896.png mask are: [ 0  5  6 11]
# Unique pixel values in the 67515.png mask are: [ 0  9 12]
# Unique pixel values in the 59324.png mask are: [0]
# Unique pixel values in the 39992.png mask are: [0 4]
# Unique pixel values in the 69846.png mask are: [0]
# Unique pixel values in the 39424.png mask are: [0 4 6]
# Unique pixel values in the 41508.png mask are: [0 4 6 8]
# Unique pixel values in the 45502.png mask are: [0 1 4]
# Unique pixel values in the 46362.png mask are: [ 0  6  9 12]
# Unique pixel values in the 45965.png mask are: [0 4]
# Unique pixel values in the 69917.png mask are: [ 0 12]
# Unique pixel values in the 69465.png mask are: [0 4 6]
# Unique pixel values in the 40043.png mask are: [0 4]
# Unique pixel values in the 69985.png mask are: [0 6]
# Unique pixel values in the 39520.png mask are: [ 0  4  8 12]
# Unique pixel values in the 48986.png mask are: [ 0  4  6 13]
# Unique pixel values in the 41467.png mask are: [0 2 4]
# Unique pixel values in the 47185.png mask are: [0 2 4 8]
# Unique pixel values in the 70355.png mask are: [0 4]
# Unique pixel values in the 45699.png mask are: [0 4 6]
# Unique pixel values in the 41817.png mask are: [0]
# Unique pixel values in the 69167.png mask are: [ 0 11]
# Unique pixel values in the 69925.png mask are: [0]
# Unique pixel values in the 62142.png mask are: [0 6]
# Unique pixel values in the 36253.png mask are: [0 1]
# Unique pixel values in the 45865.png mask are: [ 0  6 11]
# Unique pixel values in the 46030.png mask are: [ 0  2  4  6  9 13]
# Unique pixel values in the 57493.png mask are: [ 0  4  6  8 12]
# Unique pixel values in the 61912.png mask are: [ 0  4  6  9 11]
# Unique pixel values in the 39411.png mask are: [0 3 4 6 9]
# Unique pixel values in the 45769.png mask are: [0 4 6]
# Unique pixel values in the 69006.png mask are: [0 5]
# Unique pixel values in the 69384.png mask are: [ 0  6 11]
# Unique pixel values in the 45967.png mask are: [0 4]
# Unique pixel values in the 45758.png mask are: [0 3]
# Unique pixel values in the 70470.png mask are: [0 4]
# Unique pixel values in the 36200.png mask are: [0]
# Unique pixel values in the 55959.png mask are: [0 4 6 7]
# Unique pixel values in the 45608.png mask are: [0]
# Unique pixel values in the 61046.png mask are: [0 1 6]
# Unique pixel values in the 41162.png mask are: [0]
# Unique pixel values in the 46667.png mask are: [0 4 6]
# Unique pixel values in the 69588.png mask are: [0]
# Unique pixel values in the 39097.png mask are: [0 6]
# Unique pixel values in the 70324.png mask are: [0 6]
# Unique pixel values in the 69915.png mask are: [0 4 6 9]
# Unique pixel values in the 40840.png mask are: [ 0 12]
# Unique pixel values in the 70336.png mask are: [0 3 6]
# Unique pixel values in the 60972.png mask are: [ 0  3  6 12]
# Unique pixel values in the 59702.png mask are: [0 4 6]
# Unique pixel values in the 45837.png mask are: [0 4]
# Unique pixel values in the 41838.png mask are: [0 4]
# Unique pixel values in the 41115.png mask are: [0]
# Unique pixel values in the 46657.png mask are: [0 6]
# Unique pixel values in the 59321.png mask are: [0]
# Unique pixel values in the 45597.png mask are: [ 0  8 12]
# Unique pixel values in the 40468.png mask are: [0]
# Unique pixel values in the 45201.png mask are: [0 8]
# Unique pixel values in the 45634.png mask are: [ 0  1  6 13]
# Unique pixel values in the 57536.png mask are: [0 2 4 6]
# Unique pixel values in the 40002.png mask are: [0 3]
# Unique pixel values in the 40730.png mask are: [0]
# Unique pixel values in the 45957.png mask are: [0 8]
# Unique pixel values in the 56816.png mask are: [0]
# Unique pixel values in the 55942.png mask are: [0 4 6]
# Unique pixel values in the 36202.png mask are: [0]
# Unique pixel values in the 47278.png mask are: [0 2]
# Unique pixel values in the 39420.png mask are: [0 6]
# Unique pixel values in the 39128.png mask are: [ 0  4 13]
# Unique pixel values in the 57603.png mask are: [0 6]
# Unique pixel values in the 41067.png mask are: [0 2 8]
# Unique pixel values in the 55875.png mask are: [0 8]
# Unique pixel values in the 69388.png mask are: [ 0  5  6 11]
# Unique pixel values in the 55801.png mask are: [ 0  6  9 13]
# Unique pixel values in the 40376.png mask are: [ 0  4  6  8 12]
# Unique pixel values in the 55963.png mask are: [ 0  4  6  7 13]
# Unique pixel values in the 41227.png mask are: [0 4]
# Unique pixel values in the 36229.png mask are: [0]
# Unique pixel values in the 46356.png mask are: [0]
# Unique pixel values in the 41980.png mask are: [0 4]
# Unique pixel values in the 41777.png mask are: [ 0  4  8 13]
# Unique pixel values in the 69579.png mask are: [0 1 6 9]
# Unique pixel values in the 45924.png mask are: [0]
# Unique pixel values in the 70292.png mask are: [0 6]
# Unique pixel values in the 59642.png mask are: [0 3 4 6]
# Unique pixel values in the 57550.png mask are: [ 0  9 12]
# Unique pixel values in the 45874.png mask are: [ 0  6 10 11 12]
# Unique pixel values in the 48983.png mask are: [ 0 12]
# Unique pixel values in the 39794.png mask are: [ 0  4  5  8  9 12]
# Unique pixel values in the 36268.png mask are: [0]
# Unique pixel values in the 46683.png mask are: [0 6 8]
# Unique pixel values in the 62138.png mask are: [0 4 6]
# Unique pixel values in the 45523.png mask are: [0 2 9]
# Unique pixel values in the 45800.png mask are: [ 0  8 12]
# Unique pixel values in the 59684.png mask are: [0 3]
# Unique pixel values in the 56761.png mask are: [0 4]
# Unique pixel values in the 56616.png mask are: [ 0  4  5 10]
# Unique pixel values in the 70344.png mask are: [0 6]
# Unique pixel values in the 70340.png mask are: [0 4]
# Unique pixel values in the 69154.png mask are: [0 6 9]
# Unique pixel values in the 47246.png mask are: [ 0  7  8 12]
# Unique pixel values in the 67595.png mask are: [0]
# Unique pixel values in the 62088.png mask are: [ 0 11]
# Unique pixel values in the 45283.png mask are: [0]
# Unique pixel values in the 48832.png mask are: [0 4 6]
# Unique pixel values in the 68952.png mask are: [0 4]
# Unique pixel values in the 40899.png mask are: [ 0 12]
# Unique pixel values in the 48892.png mask are: [ 0  3  4  6 11]
# Unique pixel values in the 70319.png mask are: [0 4 6]
# Unique pixel values in the 60732.png mask are: [0 4 6]
# Unique pixel values in the 70950.png mask are: [0 2 4 6]
# Unique pixel values in the 56684.png mask are: [0 1]
# Unique pixel values in the 55941.png mask are: [0 4 6]
# Unique pixel values in the 41164.png mask are: [0 3 6]
# Unique pixel values in the 55954.png mask are: [0]
# Unique pixel values in the 69858.png mask are: [ 0  1  8 12]
# Unique pixel values in the 70289.png mask are: [0]
# Unique pixel values in the 41907.png mask are: [0 8]
# Unique pixel values in the 70426.png mask are: [0]
# Unique pixel values in the 61051.png mask are: [0 6 8]
# Unique pixel values in the 70473.png mask are: [0 4]
# Unique pixel values in the 69097.png mask are: [0 2 8]
# Unique pixel values in the 40789.png mask are: [0]
# Unique pixel values in the 55846.png mask are: [0 3]
# Unique pixel values in the 45940.png mask are: [ 0 11]
# Unique pixel values in the 44846.png mask are: [ 0  4 12]
# Unique pixel values in the 69914.png mask are: [0 6 9]
# Unique pixel values in the 69029.png mask are: [0]
# Unique pixel values in the 40467.png mask are: [0]
# Unique pixel values in the 58734.png mask are: [ 0  1  6  8 12]
# Unique pixel values in the 36240.png mask are: [0 6]
# Unique pixel values in the 41791.png mask are: [0 8]
# Unique pixel values in the 58714.png mask are: [0]
# Unique pixel values in the 36201.png mask are: [0]
# Unique pixel values in the 55974.png mask are: [ 0  6  7  8 12]
# Unique pixel values in the 46345.png mask are: [ 0  4 12]
# Unique pixel values in the 45935.png mask are: [0 4 6]
# Unique pixel values in the 40097.png mask are: [0 3 4]
# Unique pixel values in the 40066.png mask are: [0 4 6]
# Unique pixel values in the 41881.png mask are: [0 1 6]
# Unique pixel values in the 68869.png mask are: [ 0 12]
# Unique pixel values in the 47001.png mask are: [0 3 6]
# Unique pixel values in the 45893.png mask are: [0 4 6]
# Unique pixel values in the 42324.png mask are: [ 0  4  6 12]
# Unique pixel values in the 60199.png mask are: [0 3 4 6]
# Unique pixel values in the 40061.png mask are: [ 0  2  4 12]
# Unique pixel values in the 69430.png mask are: [ 0  9 11]
# Unique pixel values in the 60912.png mask are: [ 0  8 12]
# Unique pixel values in the 69504.png mask are: [ 0 12]
# Unique pixel values in the 39943.png mask are: [0 4]
# Unique pixel values in the 45721.png mask are: [0 1 4]
# Unique pixel values in the 39720.png mask are: [0 4]
# Unique pixel values in the 39100.png mask are: [0 4 6]
# Unique pixel values in the 47210.png mask are: [ 0  4  6  9 11 13]
# Unique pixel values in the 60773.png mask are: [0 5 6]
# Unique pixel values in the 56731.png mask are: [0]
# Unique pixel values in the 55966.png mask are: [ 0  6  8 12 13]
# Unique pixel values in the 46365.png mask are: [ 0  6 12]
# Unique pixel values in the 45683.png mask are: [0]
# Unique pixel values in the 69559.png mask are: [0 5 6 9]
# Unique pixel values in the 60844.png mask are: [ 0  4 11]
# Unique pixel values in the 69485.png mask are: [ 0  4  6 10 12]
# Unique pixel values in the 56671.png mask are: [0]
# Unique pixel values in the 39533.png mask are: [0]
# Unique pixel values in the 59287.png mask are: [0]
# Unique pixel values in the 69546.png mask are: [ 0  6  8  9 12]
# Unique pixel values in the 45719.png mask are: [0 2]
# Unique pixel values in the 39944.png mask are: [0 4]
# Unique pixel values in the 60785.png mask are: [ 0 11]
# Unique pixel values in the 68941.png mask are: [ 0 11]
# Unique pixel values in the 69396.png mask are: [ 0  4  6  9 12]
# Unique pixel values in the 70458.png mask are: [ 0  2 11]
# Unique pixel values in the 40016.png mask are: [0]
# Unique pixel values in the 45492.png mask are: [0 4 6]
# Unique pixel values in the 41210.png mask are: [ 0  3 12]
# Unique pixel values in the 45808.png mask are: [0 4]
# Unique pixel values in the 70431.png mask are: [0 5 6]
# Unique pixel values in the 57523.png mask are: [0 1]
# Unique pixel values in the 47281.png mask are: [ 0  2 11 12]
# Unique pixel values in the 41956.png mask are: [0]
# Unique pixel values in the 70474.png mask are: [0 4 6]
# Unique pixel values in the 46037.png mask are: [0 2 4 6 9]
# Unique pixel values in the 62151.png mask are: [0 5]
# Unique pixel values in the 69158.png mask are: [ 0  3 11]
# Unique pixel values in the 60849.png mask are: [ 0  4 11]
# Unique pixel values in the 41909.png mask are: [0]
# Unique pixel values in the 48853.png mask are: [0 4 6]
# Unique pixel values in the 62050.png mask are: [ 0  4  5  6  9 13]
# Unique pixel values in the 69133.png mask are: [0 4 9]
# Unique pixel values in the 41876.png mask are: [0 6]
# Unique pixel values in the 69528.png mask are: [0 1 6]
# Unique pixel values in the 70389.png mask are: [ 0  6 11]
# Unique pixel values in the 60744.png mask are: [ 0  1  6 12]
# Unique pixel values in the 40037.png mask are: [0]
# Unique pixel values in the 45630.png mask are: [0]
# Unique pixel values in the 45805.png mask are: [0 4]
# Unique pixel values in the 41202.png mask are: [ 0  1  4 13]
# Unique pixel values in the 70471.png mask are: [0 4 6]
# Unique pixel values in the 45521.png mask are: [0 8]
# Unique pixel values in the 58752.png mask are: [0 1 4 6 7]
# Unique pixel values in the 45928.png mask are: [0 4]
# Unique pixel values in the 58522.png mask are: [0 4 6]
# Unique pixel values in the 41858.png mask are: [0]
# Unique pixel values in the 45672.png mask are: [0 4 6 9]
# Unique pixel values in the 70338.png mask are: [0 5]
# Unique pixel values in the 45202.png mask are: [0 8]
# Unique pixel values in the 60990.png mask are: [ 0  4 10 13]
# Unique pixel values in the 58677.png mask are: [0]
# Unique pixel values in the 39495.png mask are: [ 0  4  6 12 13]
# Unique pixel values in the 68883.png mask are: [0 9]
# Unique pixel values in the 70913.png mask are: [0 4 6]
# Unique pixel values in the 61704.png mask are: [ 0  4  6  9 11]
# Unique pixel values in the 40750.png mask are: [0]
# Unique pixel values in the 70339.png mask are: [ 0  9 12]
# Unique pixel values in the 58715.png mask are: [0 8]
# Unique pixel values in the 61922.png mask are: [ 0  6 10]
# Unique pixel values in the 46028.png mask are: [ 0  4  6  8  9 12]
# Unique pixel values in the 57843.png mask are: [ 0 11]
# Unique pixel values in the 67539.png mask are: [0 6]
# Unique pixel values in the 45620.png mask are: [ 0  1  4 12 13]
# Unique pixel values in the 39105.png mask are: [0 4 7]
# Unique pixel values in the 41118.png mask are: [0 2 4]
# Unique pixel values in the 45961.png mask are: [0]
# Unique pixel values in the 56602.png mask are: [0]
# Unique pixel values in the 44856.png mask are: [ 0 11]
# Unique pixel values in the 70350.png mask are: [0]
# Unique pixel values in the 39077.png mask are: [0]
# Unique pixel values in the 40116.png mask are: [0]
# Unique pixel values in the 40745.png mask are: [0 4 7 8]
# Unique pixel values in the 61043.png mask are: [ 0 11]
# Unique pixel values in the 69867.png mask are: [ 0 12]
# Unique pixel values in the 69045.png mask are: [ 0 11]
# Unique pixel values in the 42334.png mask are: [0 2]
# Unique pixel values in the 56748.png mask are: [0]
# Unique pixel values in the 45644.png mask are: [0 6]
# Unique pixel values in the 56809.png mask are: [ 0 12]
# Unique pixel values in the 58665.png mask are: [0]
# Unique pixel values in the 70934.png mask are: [0 3 4 6]
# Unique pixel values in the 69532.png mask are: [0 4 6]
# Unique pixel values in the 46926.png mask are: [0]
# Unique pixel values in the 69060.png mask are: [0 2]
# Unique pixel values in the 68945.png mask are: [ 0  6  9 13]
# Unique pixel values in the 57548.png mask are: [ 0  5 10 11]
# Unique pixel values in the 45628.png mask are: [0 4 6]
# Unique pixel values in the 69099.png mask are: [0 6 8]
# Unique pixel values in the 57589.png mask are: [ 0  2 11]
# Unique pixel values in the 46376.png mask are: [ 0 12]
# Unique pixel values in the 45876.png mask are: [ 0 11]
# Unique pixel values in the 45964.png mask are: [0 4]
# Unique pixel values in the 48943.png mask are: [ 0  8  9 12]
# Unique pixel values in the 69863.png mask are: [0]
# Unique pixel values in the 41135.png mask are: [0]
# Unique pixel values in the 40022.png mask are: [0]
# Unique pixel values in the 41889.png mask are: [0]
# Unique pixel values in the 45524.png mask are: [ 0  3 10]
# Unique pixel values in the 45848.png mask are: [ 0  9 11 12]
# Unique pixel values in the 70028.png mask are: [0 2 6]
# Unique pixel values in the 46990.png mask are: [0 3]
# Unique pixel values in the 40855.png mask are: [0 6]
# Unique pixel values in the 69942.png mask are: [ 0  9 13]
# Unique pixel values in the 45633.png mask are: [ 0  4 13]
# Unique pixel values in the 45979.png mask are: [ 0 13]
# Unique pixel values in the 59428.png mask are: [0 1 4 6]
# Unique pixel values in the 57618.png mask are: [0 4 6]
# Unique pixel values in the 60253.png mask are: [ 0  4 11]
# Unique pixel values in the 70309.png mask are: [0]
# Unique pixel values in the 45260.png mask are: [0 8]
# Unique pixel values in the 39426.png mask are: [0 4 6]
# Unique pixel values in the 39447.png mask are: [ 0  4 12]
# Unique pixel values in the 67513.png mask are: [0 5]
# Unique pixel values in the 68896.png mask are: [ 0  4 11]
# Unique pixel values in the 45198.png mask are: [ 0 11]
# Unique pixel values in the 57614.png mask are: [0 1 8]
# Unique pixel values in the 45310.png mask are: [0 4 6]
# Unique pixel values in the 69861.png mask are: [ 0  3  6  8 12]
# Unique pixel values in the 69884.png mask are: [ 0 10 11]
# Unique pixel values in the 40870.png mask are: [0]
# Unique pixel values in the 59061.png mask are: [0 8]
# Unique pixel values in the 69071.png mask are: [0 6]
# Unique pixel values in the 60871.png mask are: [0]
# Unique pixel values in the 56793.png mask are: [ 0  4  6  9 11]
# Unique pixel values in the 56003.png mask are: [ 0  7  8  9 12]
# Unique pixel values in the 39999.png mask are: [ 0 11]
# Unique pixel values in the 45649.png mask are: [ 0  4  6  8 13]
# Unique pixel values in the 69038.png mask are: [0 6]
# Unique pixel values in the 55958.png mask are: [0 4 6]
# Unique pixel values in the 69456.png mask are: [0]
# Unique pixel values in the 45510.png mask are: [ 0  1 12]
# Unique pixel values in the 57664.png mask are: [0 4 5 6]
# Unique pixel values in the 39485.png mask are: [0 3 4 6]
# Unique pixel values in the 45900.png mask are: [0 4 6]
# Unique pixel values in the 45733.png mask are: [0]
# Unique pixel values in the 59591.png mask are: [0 2]
# Unique pixel values in the 69470.png mask are: [0 6]
# Unique pixel values in the 69398.png mask are: [0 8]
# Unique pixel values in the 59426.png mask are: [0 3]
# Unique pixel values in the 45271.png mask are: [0 4 9]
# Unique pixel values in the 68950.png mask are: [ 0  6 11]
# Unique pixel values in the 68917.png mask are: [0 6 9]
# Unique pixel values in the 68923.png mask are: [0 1 9]
# Unique pixel values in the 36295.png mask are: [0]
# Unique pixel values in the 60978.png mask are: [ 0 11]
# Unique pixel values in the 69940.png mask are: [ 0  6  9 13]
# Unique pixel values in the 48860.png mask are: [0 4]
# Unique pixel values in the 68996.png mask are: [0 9]
# Unique pixel values in the 58816.png mask are: [0]
# Unique pixel values in the 59505.png mask are: [0 4]
# Unique pixel values in the 39738.png mask are: [0 2]
# Unique pixel values in the 58841.png mask are: [0 4 6]
# Unique pixel values in the 60806.png mask are: [ 0  4  6 10 13]
# Unique pixel values in the 56677.png mask are: [0]
# Unique pixel values in the 41191.png mask are: [0 6]
# Unique pixel values in the 41969.png mask are: [0 2 8]
# Unique pixel values in the 48921.png mask are: [0 4 8]
# Unique pixel values in the 45281.png mask are: [0 4 9]
# Unique pixel values in the 67620.png mask are: [0]
# Unique pixel values in the 70467.png mask are: [0]
# Unique pixel values in the 69883.png mask are: [ 0  4 10]
# Unique pixel values in the 61045.png mask are: [0 8]
# Unique pixel values in the 41457.png mask are: [0]
# Unique pixel values in the 40071.png mask are: [ 0  4  6 12 13]
# Unique pixel values in the 45286.png mask are: [0]
# Unique pixel values in the 70472.png mask are: [0 3 6]
# Unique pixel values in the 41878.png mask are: [0 4]
# Unique pixel values in the 45594.png mask are: [0 6 9]
# Unique pixel values in the 41163.png mask are: [0 3 6]
# Unique pixel values in the 58649.png mask are: [0 4 6]
# Unique pixel values in the 46677.png mask are: [ 0 12]
# Unique pixel values in the 46641.png mask are: [0 4 6]
# Unique pixel values in the 39747.png mask are: [ 0 13]
# Unique pixel values in the 57891.png mask are: [ 0  9 12]
# Unique pixel values in the 46988.png mask are: [ 0 10]
# Unique pixel values in the 69087.png mask are: [ 0  6 10]
# Unique pixel values in the 45195.png mask are: [ 0  4  7  8  9 12]
# Unique pixel values in the 41973.png mask are: [0 4]
# Unique pixel values in the 40433.png mask are: [0 8]
# Unique pixel values in the 40101.png mask are: [ 0  3  8 12]
# Unique pixel values in the 70353.png mask are: [0 3 6]
# Unique pixel values in the 69484.png mask are: [0 6]
# Unique pixel values in the 44845.png mask are: [ 0  4  6 13]
# Unique pixel values in the 39474.png mask are: [ 0 13]
# Unique pixel values in the 41116.png mask are: [0 2]
# Unique pixel values in the 56749.png mask are: [ 0  9 11]
# Unique pixel values in the 57579.png mask are: [0 2]
# Unique pixel values in the 45642.png mask are: [ 0 12]
# Unique pixel values in the 40854.png mask are: [0 6]
# Unique pixel values in the 60749.png mask are: [0]
# Unique pixel values in the 45261.png mask are: [0 4 6]
# Unique pixel values in the 59492.png mask are: [0 4 6]
# Unique pixel values in the 70891.png mask are: [0 6]
# Unique pixel values in the 41888.png mask are: [0]
# Unique pixel values in the 48919.png mask are: [0]
# Unique pixel values in the 39698.png mask are: [ 0  4  6  8 10]
# Unique pixel values in the 59563.png mask are: [0 6]
# Unique pixel values in the 68885.png mask are: [0 4 6 9]
# Unique pixel values in the 36327.png mask are: [0]
# Unique pixel values in the 60890.png mask are: [ 0  4  6 11]
# Unique pixel values in the 45899.png mask are: [0 4 6]
# Unique pixel values in the 47231.png mask are: [ 0  4  6 11]
# Unique pixel values in the 41997.png mask are: [ 0  8 12]
# Unique pixel values in the 45681.png mask are: [ 0  4  6 12]
# Unique pixel values in the 45752.png mask are: [ 0  4  7 12]
# Unique pixel values in the 49001.png mask are: [0 4]
# Unique pixel values in the 39441.png mask are: [ 0  1  8 11 12]
# Unique pixel values in the 39692.png mask are: [0 4 8]
# Unique pixel values in the 69175.png mask are: [0 2]
# Unique pixel values in the 36239.png mask are: [0 6]
# Unique pixel values in the 46982.png mask are: [0 3 4 6 7 9]
# Unique pixel values in the 39499.png mask are: [0]
# Unique pixel values in the 69929.png mask are: [0 6]
# Unique pixel values in the 46922.png mask are: [ 0  4  6  7  8 10 11]
# Unique pixel values in the 39490.png mask are: [0 1]
# Unique pixel values in the 45812.png mask are: [0 4]
# Unique pixel values in the 45824.png mask are: [0 1 4 9]
# Unique pixel values in the 45829.png mask are: [0 4 6]
# Unique pixel values in the 58860.png mask are: [0 2]
# Unique pixel values in the 70386.png mask are: [0 5]
# Unique pixel values in the 39529.png mask are: [0 2]
# Unique pixel values in the 62035.png mask are: [0 7]
# Unique pixel values in the 60789.png mask are: [ 0 11]
# Unique pixel values in the 45490.png mask are: [ 0  4  6 10 12]
# Unique pixel values in the 59443.png mask are: [0 4 6]
# Unique pixel values in the 68938.png mask are: [0]
# Unique pixel values in the 45773.png mask are: [0 4 6]
# Unique pixel values in the 59488.png mask are: [0 6]
# Unique pixel values in the 45639.png mask are: [ 0  1  4 10]
# Unique pixel values in the 39722.png mask are: [0 1 4]
# Unique pixel values in the 36386.png mask are: [0 1 6]
# Unique pixel values in the 45731.png mask are: [0]
# Unique pixel values in the 70047.png mask are: [0 4]
# Unique pixel values in the 61882.png mask are: [0 4 6]
# Unique pixel values in the 45250.png mask are: [0 8]
# Unique pixel values in the 69149.png mask are: [0 6 8]
# Unique pixel values in the 70059.png mask are: [0 5 6]
# Unique pixel values in the 40869.png mask are: [0]
# Unique pixel values in the 70459.png mask are: [0 4]
# Unique pixel values in the 46347.png mask are: [0 4 6]
# Unique pixel values in the 39706.png mask are: [0]
# Unique pixel values in the 46661.png mask are: [0 6]
# Unique pixel values in the 45896.png mask are: [0]
# Unique pixel values in the 70006.png mask are: [0 6]
# Unique pixel values in the 42339.png mask are: [ 0  4 12]
# Unique pixel values in the 69005.png mask are: [0 4 5]
# Unique pixel values in the 40389.png mask are: [0 3]
# Unique pixel values in the 45256.png mask are: [0]
# Unique pixel values in the 59708.png mask are: [ 0  1 12]
# Unique pixel values in the 67572.png mask are: [ 0  7  8 12]
# Unique pixel values in the 61701.png mask are: [ 0  1  4  6  9 13]
# Unique pixel values in the 56715.png mask are: [ 0  5  8 11]
# Unique pixel values in the 41993.png mask are: [ 0  8 12]
# Unique pixel values in the 45892.png mask are: [0 4]
# Unique pixel values in the 40874.png mask are: [0 8]
# Unique pixel values in the 41994.png mask are: [ 0  4  8 12]
# Unique pixel values in the 45705.png mask are: [0 4 6]
# Unique pixel values in the 69525.png mask are: [0 6]
# Unique pixel values in the 59498.png mask are: [ 0  6 12]
# Unique pixel values in the 59257.png mask are: [0 4 6]
# Unique pixel values in the 45491.png mask are: [0]
# Unique pixel values in the 48884.png mask are: [0 6 9]
# Unique pixel values in the 39516.png mask are: [ 0  4  6 12]
# Unique pixel values in the 60743.png mask are: [0 4 6]
# Unique pixel values in the 59646.png mask are: [ 0  6 11]
# Unique pixel values in the 57553.png mask are: [ 0 11]
# Unique pixel values in the 46959.png mask are: [0 6]
# Unique pixel values in the 45656.png mask are: [0]
# Unique pixel values in the 41073.png mask are: [ 0  4 13]
# Unique pixel values in the 45496.png mask are: [ 0  1  4  6  9 12]
# Unique pixel values in the 40862.png mask are: [0]
# Unique pixel values in the 69564.png mask are: [0]
# Unique pixel values in the 41448.png mask are: [0]
# Unique pixel values in the 58773.png mask are: [0 3]
# Unique pixel values in the 40100.png mask are: [ 0  8 12]
# Unique pixel values in the 56788.png mask are: [ 0  9 11 12]
# Unique pixel values in the 47234.png mask are: [ 0  4  6 11]
# Unique pixel values in the 39998.png mask are: [0]
# Unique pixel values in the 60771.png mask are: [ 0  5  6 11]
# Unique pixel values in the 69840.png mask are: [ 0  4  6 12]
# Unique pixel values in the 56023.png mask are: [ 0 13]
# Unique pixel values in the 40381.png mask are: [ 0  4  8 12]
# Unique pixel values in the 41449.png mask are: [0]
# Unique pixel values in the 36244.png mask are: [ 0  4 12 13]
# Unique pixel values in the 55936.png mask are: [0 4]
# Unique pixel values in the 39719.png mask are: [0]
# Unique pixel values in the 69040.png mask are: [0 6]
# Unique pixel values in the 40814.png mask are: [0 1 6]
# Unique pixel values in the 62028.png mask are: [0]
# Unique pixel values in the 48820.png mask are: [0 6 8]
# Unique pixel values in the 48896.png mask are: [ 0  4  6  9 10 11 12]
# Unique pixel values in the 70417.png mask are: [0 4 6 9]
# Unique pixel values in the 59662.png mask are: [0 8]
# Unique pixel values in the 59252.png mask are: [0]
# Unique pixel values in the 56015.png mask are: [0]
# Unique pixel values in the 61013.png mask are: [ 0  7 13]
# Unique pixel values in the 61719.png mask are: [ 0  4  6 13]
# Unique pixel values in the 39733.png mask are: [0 2]
# Unique pixel values in the 70281.png mask are: [0 6 8]
# Unique pixel values in the 47212.png mask are: [0]
# Unique pixel values in the 69454.png mask are: [ 0 11]
# Unique pixel values in the 41874.png mask are: [0 6]
# Unique pixel values in the 70440.png mask are: [0]
# Unique pixel values in the 69379.png mask are: [ 0  6 11]
# Unique pixel values in the 45723.png mask are: [0 1]
# Unique pixel values in the 67563.png mask are: [0 4]
# Unique pixel values in the 40013.png mask are: [0 3 6 8]
# Unique pixel values in the 47010.png mask are: [0 9]
# Unique pixel values in the 45772.png mask are: [0 4 6]
# Unique pixel values in the 41237.png mask are: [0 4 6 8]
# Unique pixel values in the 58534.png mask are: [0 4 6]
# Unique pixel values in the 41204.png mask are: [ 0  4 13]
# Unique pixel values in the 60883.png mask are: [ 0  4 11]
# Unique pixel values in the 57881.png mask are: [ 0  4  6  9 11 12]
# Unique pixel values in the 70327.png mask are: [0 3 4 6]
# Unique pixel values in the 59669.png mask are: [ 0 10 11]
# Unique pixel values in the 59530.png mask are: [ 0  6 13]
# Unique pixel values in the 69156.png mask are: [0 6 9]
# Unique pixel values in the 60220.png mask are: [ 0  9 12]
# Unique pixel values in the 46689.png mask are: [0 4 6 8]
# Unique pixel values in the 45782.png mask are: [0 4 6]
# Unique pixel values in the 56812.png mask are: [0 5]
# Unique pixel values in the 57514.png mask are: [0 1]
# Unique pixel values in the 69401.png mask are: [0 9]
# Unique pixel values in the 45700.png mask are: [0 4 6]
# Unique pixel values in the 68964.png mask are: [0]
# Unique pixel values in the 48883.png mask are: [0 6 9]
# Unique pixel values in the 70949.png mask are: [0 3 6]
# Unique pixel values in the 59596.png mask are: [0 3 4 6]
# Unique pixel values in the 70377.png mask are: [0 4 6]
# Unique pixel values in the 46971.png mask are: [0 4]
# Unique pixel values in the 56685.png mask are: [0 4]
# Unique pixel values in the 59059.png mask are: [0 6 9]
# Unique pixel values in the 57698.png mask are: [0 1 6]
# Unique pixel values in the 58861.png mask are: [ 0  7  8 12]
# Unique pixel values in the 45798.png mask are: [ 0  4  6 12]
# Unique pixel values in the 68928.png mask are: [0 9]
# Unique pixel values in the 69487.png mask are: [0 6]
# Unique pixel values in the 45625.png mask are: [0]
# Unique pixel values in the 40744.png mask are: [ 0  7  8 11]
# Unique pixel values in the 58724.png mask are: [ 0  6 10]
# Unique pixel values in the 60982.png mask are: [ 0 11]
# Unique pixel values in the 67548.png mask are: [0 9]
# Unique pixel values in the 36329.png mask are: [0 6]
# Unique pixel values in the 68901.png mask are: [0 5]
# Unique pixel values in the 59263.png mask are: [ 0  6 12 13]
# Unique pixel values in the 45233.png mask are: [0]
# Unique pixel values in the 48981.png mask are: [0]
# Unique pixel values in the 70358.png mask are: [0 5 6]
# Unique pixel values in the 58768.png mask are: [0]
# Unique pixel values in the 48836.png mask are: [ 0 12]
# Unique pixel values in the 41493.png mask are: [0 4 6]
# Unique pixel values in the 45227.png mask are: [ 0  1  4  6 11 13]
# Unique pixel values in the 69500.png mask are: [ 0  6 12]
# Unique pixel values in the 70034.png mask are: [0 3 6]
# Unique pixel values in the 59647.png mask are: [0 6]
# Unique pixel values in the 47171.png mask are: [0 4]
# Unique pixel values in the 36299.png mask are: [0 6]
# Unique pixel values in the 59697.png mask are: [0 4 6]
# Unique pixel values in the 45909.png mask are: [0 4 6]
# Unique pixel values in the 56722.png mask are: [0]
# Unique pixel values in the 45775.png mask are: [0 4 6 7]
# Unique pixel values in the 47174.png mask are: [0]
# Unique pixel values in the 70437.png mask are: [ 0  7 10]
# Unique pixel values in the 45697.png mask are: [ 0 12]
# Unique pixel values in the 46379.png mask are: [ 0  8 12]
# Unique pixel values in the 60758.png mask are: [ 0  4  6  8  9 12 13]
# Unique pixel values in the 69918.png mask are: [0 5 6]
# Unique pixel values in the 41824.png mask are: [0 1 8]
# Unique pixel values in the 69077.png mask are: [0 4 6]
# Unique pixel values in the 45193.png mask are: [ 0  4  7  8  9 12]
# Unique pixel values in the 45320.png mask are: [0 8]
# Unique pixel values in the 45739.png mask are: [ 0  4  6 13]
# Unique pixel values in the 40047.png mask are: [0 4]
# Unique pixel values in the 56627.png mask are: [0 7 8]
# Unique pixel values in the 69832.png mask are: [0]
# Unique pixel values in the 45264.png mask are: [0 4]
# Unique pixel values in the 59268.png mask are: [ 0  6 13]
# Unique pixel values in the 41844.png mask are: [0 4 6]
# Unique pixel values in the 45743.png mask are: [ 0  4  6 12]
# Unique pixel values in the 46950.png mask are: [0 4 6]
# Unique pixel values in the 55900.png mask are: [0 4 6]
# Unique pixel values in the 69032.png mask are: [0]
# Unique pixel values in the 46381.png mask are: [ 0  8 12]
# Unique pixel values in the 40000.png mask are: [0 1]
# Unique pixel values in the 48954.png mask are: [ 0  4  6 13]
# Unique pixel values in the 39074.png mask are: [0 4 6]
# Unique pixel values in the 59450.png mask are: [0 6]
# Unique pixel values in the 62027.png mask are: [0]
# Unique pixel values in the 58871.png mask are: [0 1]
# Unique pixel values in the 40406.png mask are: [0 4]
# Unique pixel values in the 60750.png mask are: [0 8]
# Unique pixel values in the 45667.png mask are: [0 4 6]
# Unique pixel values in the 47273.png mask are: [0 4 6]
# Unique pixel values in the 69488.png mask are: [0 6]
# Unique pixel values in the 41773.png mask are: [ 0  4  6  8 13]
# Unique pixel values in the 41987.png mask are: [0 4 6]
# Unique pixel values in the 56774.png mask are: [ 0  4  6 10]
# Unique pixel values in the 56689.png mask are: [ 0  9 12]
# Unique pixel values in the 39725.png mask are: [ 0  8 12]
# Unique pixel values in the 61925.png mask are: [ 0 10 12]
# Unique pixel values in the 60862.png mask are: [ 0  4  5 11]
# Unique pixel values in the 39135.png mask are: [0 4 6]
# Unique pixel values in the 42348.png mask are: [0 8]
# Unique pixel values in the 68889.png mask are: [0 6 9]
# Unique pixel values in the 39449.png mask are: [0 4 8 9]
# Unique pixel values in the 41092.png mask are: [0]
# Unique pixel values in the 61710.png mask are: [0 4]
# Unique pixel values in the 39742.png mask are: [0]
# Unique pixel values in the 69441.png mask are: [0]
# Unique pixel values in the 39413.png mask are: [ 0  9 10 11]
# Unique pixel values in the 39137.png mask are: [ 0  4  6 13]
# Unique pixel values in the 70334.png mask are: [0 5 6]
# Unique pixel values in the 70454.png mask are: [0 5]
# Unique pixel values in the 55927.png mask are: [0 4]
# Unique pixel values in the 45651.png mask are: [ 0  4  6  8 12]
# Unique pixel values in the 60202.png mask are: [0 3 6]
# Unique pixel values in the 70508.png mask are: [0 4]
# Unique pixel values in the 58845.png mask are: [ 0  4 13]
# Unique pixel values in the 41472.png mask are: [0 2 6]
# Unique pixel values in the 68895.png mask are: [0 5]
# Unique pixel values in the 57645.png mask are: [ 0  5  6 11]
# Unique pixel values in the 69899.png mask are: [0 3 6]
# Unique pixel values in the 59277.png mask are: [ 0  4  6 10]
# Unique pixel values in the 45469.png mask are: [0 4 6]
# Unique pixel values in the 40741.png mask are: [0 7 8]
# Unique pixel values in the 57570.png mask are: [0 4 6]
# Unique pixel values in the 48893.png mask are: [0 4]
# Unique pixel values in the 60761.png mask are: [ 0  4  6  8  9 13]
# Unique pixel values in the 56651.png mask are: [0]
# Unique pixel values in the 39475.png mask are: [0]
# Unique pixel values in the 56802.png mask are: [ 0  4  6 13]
# Unique pixel values in the 60222.png mask are: [ 0 12]
# Unique pixel values in the 58817.png mask are: [0]
# Unique pixel values in the 57741.png mask are: [ 0  4  6  8  9 12]
# Unique pixel values in the 58567.png mask are: [ 0 10]
# Unique pixel values in the 41470.png mask are: [0 2 6]
# Unique pixel values in the 48905.png mask are: [0 4]
# Unique pixel values in the 41482.png mask are: [0 3]
# Unique pixel values in the 45654.png mask are: [0 6]
# Unique pixel values in the 68879.png mask are: [0 6]
# Unique pixel values in the 70384.png mask are: [0 6]
# Unique pixel values in the 36308.png mask are: [0 2 6 8]
# Unique pixel values in the 45497.png mask are: [0 4 6 9]
# Unique pixel values in the 46904.png mask are: [0 6]
# Unique pixel values in the 55961.png mask are: [0 4 6 7]
# Unique pixel values in the 48887.png mask are: [0 6 9]
# Unique pixel values in the 41066.png mask are: [0]
# Unique pixel values in the 59304.png mask are: [ 0  6 12]
# Unique pixel values in the 69566.png mask are: [ 0 12]
# Unique pixel values in the 46947.png mask are: [0 4 6]
# Unique pixel values in the 40771.png mask are: [0 4 6]
# Unique pixel values in the 67615.png mask are: [0]
# Unique pixel values in the 39726.png mask are: [0 1]
# Unique pixel values in the 40457.png mask are: [ 0 12]
# Unique pixel values in the 57494.png mask are: [0 3]
# Unique pixel values in the 45931.png mask are: [0 4 6]
# Unique pixel values in the 69120.png mask are: [0 3 4]
# Unique pixel values in the 58617.png mask are: [0 4]
# Unique pixel values in the 42358.png mask are: [ 0  8 11]
# Unique pixel values in the 48829.png mask are: [0]
# Unique pixel values in the 39512.png mask are: [ 0  4  6  9 12]
# Unique pixel values in the 41770.png mask are: [0 4 6 8]
# Unique pixel values in the 46001.png mask are: [0 4 6]
# Unique pixel values in the 58596.png mask are: [0 4 6]
# Unique pixel values in the 40871.png mask are: [0]
# Unique pixel values in the 48889.png mask are: [0 6 9]
# Unique pixel values in the 45479.png mask are: [ 0  8  9 12]
# Unique pixel values in the 39987.png mask are: [0 4]
# Unique pixel values in the 40461.png mask are: [0 3 4]
# Unique pixel values in the 41474.png mask are: [0 2 6]
# Unique pixel values in the 40448.png mask are: [ 0 12]
# Unique pixel values in the 41471.png mask are: [0 2 6]
# Unique pixel values in the 41185.png mask are: [0 1]
# Unique pixel values in the 36264.png mask are: [0 4 6]
# Unique pixel values in the 69574.png mask are: [0]
# Unique pixel values in the 39527.png mask are: [0]
# Unique pixel values in the 62121.png mask are: [0 2]
# Unique pixel values in the 45748.png mask are: [ 0  4  7 12]
# Unique pixel values in the 36263.png mask are: [0 6]
# Unique pixel values in the 70488.png mask are: [ 0  3  9 12]
# Unique pixel values in the 56657.png mask are: [0 8]
# Unique pixel values in the 40859.png mask are: [0 6]
# Unique pixel values in the 39508.png mask are: [ 0  6  9 12]
# Unique pixel values in the 56603.png mask are: [0 1]
# Unique pixel values in the 46377.png mask are: [0]
# Unique pixel values in the 58867.png mask are: [0]
# Unique pixel values in the 69996.png mask are: [0 6]
# Unique pixel values in the 47276.png mask are: [0 6]
# Unique pixel values in the 70478.png mask are: [0 3]
# Unique pixel values in the 69003.png mask are: [0]
# Unique pixel values in the 45760.png mask are: [ 0 11]
# Unique pixel values in the 46966.png mask are: [0 2]
# Unique pixel values in the 61077.png mask are: [0 4 6]
# Unique pixel values in the 39131.png mask are: [ 0  4  6 13]
# Unique pixel values in the 69931.png mask are: [0]
# Unique pixel values in the 55897.png mask are: [ 0  4  6 13]
# Unique pixel values in the 68906.png mask are: [0]
# Unique pixel values in the 36319.png mask are: [0]
# Unique pixel values in the 44851.png mask are: [ 0  8 12]
# Unique pixel values in the 68892.png mask are: [0 6 9]
# Unique pixel values in the 57467.png mask are: [ 0  4  6  9 10 11 12]
# Unique pixel values in the 41971.png mask are: [0 2 8]
# Unique pixel values in the 70367.png mask are: [0 4]
# Unique pixel values in the 48890.png mask are: [0 6 9]
# Unique pixel values in the 58803.png mask are: [ 0 10]
# Unique pixel values in the 48988.png mask are: [ 0  4  6 13]
# Unique pixel values in the 70920.png mask are: [0 9]
# Unique pixel values in the 45738.png mask are: [ 0  4  6 13]
# Unique pixel values in the 57549.png mask are: [ 0  8 11]
# Unique pixel values in the 45666.png mask are: [ 0  4  6 13]
# Unique pixel values in the 60867.png mask are: [0 4 5]
# Unique pixel values in the 41468.png mask are: [0 2 6]
# Unique pixel values in the 39942.png mask are: [0 4]
# Unique pixel values in the 55947.png mask are: [ 0 12]
# Unique pixel values in the 69593.png mask are: [0]
# Unique pixel values in the 57850.png mask are: [ 0  4  6  9 11]
# Unique pixel values in the 46015.png mask are: [ 0 12]
# Unique pixel values in the 45962.png mask are: [0 8]
# Unique pixel values in the 41451.png mask are: [0 1 4]
# Unique pixel values in the 69871.png mask are: [0 4 6]
# Unique pixel values in the 69869.png mask are: [ 0  8 11]
# Unique pixel values in the 69440.png mask are: [ 0  4  6 11]
# Unique pixel values in the 45232.png mask are: [0]
# Unique pixel values in the 47178.png mask are: [0 4]
# Unique pixel values in the 39445.png mask are: [ 0  4 12]
# Unique pixel values in the 59522.png mask are: [0]
# Unique pixel values in the 45946.png mask are: [0 3 4]
# Unique pixel values in the 61906.png mask are: [ 0  2  8 12]
# Unique pixel values in the 41790.png mask are: [0 4]
# Unique pixel values in the 69547.png mask are: [0 4 6 9]
# Unique pixel values in the 69952.png mask are: [0 5 6]
# Unique pixel values in the 46983.png mask are: [0]
# Unique pixel values in the 41861.png mask are: [0]
# Unique pixel values in the 41452.png mask are: [ 0  8 11]
# Unique pixel values in the 45504.png mask are: [0]
# Unique pixel values in the 39534.png mask are: [ 0  2 11]
# Unique pixel values in the 45692.png mask are: [ 0 12]
# Unique pixel values in the 47008.png mask are: [ 0  2 11]
# Unique pixel values in the 48881.png mask are: [0 8]
# Unique pixel values in the 69092.png mask are: [ 0 10]
# Unique pixel values in the 69443.png mask are: [0]
# Unique pixel values in the 69426.png mask are: [0 4 6]
# Unique pixel values in the 69001.png mask are: [0]
# Unique pixel values in the 59658.png mask are: [0 6 9]
# Unique pixel values in the 45901.png mask are: [0 4 6]
# Unique pixel values in the 60793.png mask are: [0 4]
# Unique pixel values in the 58797.png mask are: [0 1 6 7]
# Unique pixel values in the 67526.png mask are: [0 4]
# Unique pixel values in the 39446.png mask are: [0 4]
# Unique pixel values in the 61709.png mask are: [0 9]
# Unique pixel values in the 59626.png mask are: [ 0  6  7 12]
# Unique pixel values in the 45854.png mask are: [0]
# Unique pixel values in the 45321.png mask are: [0 8]
# Unique pixel values in the 68867.png mask are: [0 5 6]
# Unique pixel values in the 68960.png mask are: [ 0  4 13]
# Unique pixel values in the 70906.png mask are: [0 1 4]
# Unique pixel values in the 40073.png mask are: [0 1 4]
# Unique pixel values in the 47290.png mask are: [ 0  2 11 12]
# Unique pixel values in the 67613.png mask are: [0 6 8]
# Unique pixel values in the 46046.png mask are: [0 4 6]
# Unique pixel values in the 70883.png mask are: [0 4 6]
# Unique pixel values in the 69865.png mask are: [0 6]
# Unique pixel values in the 45871.png mask are: [ 0  6 10 11]
# Unique pixel values in the 68969.png mask are: [ 0  1 11]
# Unique pixel values in the 69444.png mask are: [ 0 13]
# Unique pixel values in the 69530.png mask are: [0 3 4 6]
# Unique pixel values in the 40769.png mask are: [0 1 6 8]
# Unique pixel values in the 58833.png mask are: [ 0  1 12]
# Unique pixel values in the 40093.png mask are: [0 3 4]
# Unique pixel values in the 70295.png mask are: [0 4 6]
# Unique pixel values in the 70475.png mask are: [0 6]
# Unique pixel values in the 69981.png mask are: [0 4]
# Unique pixel values in the 36248.png mask are: [0 8]
# Unique pixel values in the 69026.png mask are: [0]
# Unique pixel values in the 48967.png mask are: [0 2 4 6 8]
# Unique pixel values in the 59298.png mask are: [ 0  6 12]
# Unique pixel values in the 70923.png mask are: [0 6]
# Unique pixel values in the 48938.png mask are: [0]
# Unique pixel values in the 48920.png mask are: [0]
# Unique pixel values in the 41520.png mask are: [0 7 8 9]
# Unique pixel values in the 70383.png mask are: [0 3 4 6]
# Unique pixel values in the 39978.png mask are: [0 7]
# Unique pixel values in the 57482.png mask are: [ 0  4  6 12 13]
# Unique pixel values in the 69901.png mask are: [0 4]
# Unique pixel values in the 45663.png mask are: [0]
# Unique pixel values in the 48830.png mask are: [ 0 11]
# Unique pixel values in the 46921.png mask are: [ 0  4  6  7  8 10 11]
# Unique pixel values in the 69116.png mask are: [ 0  6  8 11]
# Unique pixel values in the 40809.png mask are: [0 6]
# Unique pixel values in the 69427.png mask are: [0 6]
# Unique pixel values in the 69955.png mask are: [ 0  6 13]
# Unique pixel values in the 60780.png mask are: [0 9]
# Unique pixel values in the 46026.png mask are: [0 4]
# Unique pixel values in the 41823.png mask are: [0 4 9]
# Unique pixel values in the 45486.png mask are: [0 4]
# Unique pixel values in the 45472.png mask are: [0 4 6]
# Unique pixel values in the 40380.png mask are: [ 0  4  8 12]
# Unique pixel values in the 47289.png mask are: [ 0  2  4 12]
# Unique pixel values in the 45527.png mask are: [0 6]
# Unique pixel values in the 40889.png mask are: [0 1]
# Unique pixel values in the 39729.png mask are: [0 1]
# Unique pixel values in the 45473.png mask are: [0 8]
# Unique pixel values in the 57649.png mask are: [0 4 5 6]
# Unique pixel values in the 70011.png mask are: [0 3 6]
# Unique pixel values in the 45631.png mask are: [0]
# Unique pixel values in the 41806.png mask are: [ 0  4  7 10]
# Unique pixel values in the 40463.png mask are: [0]
# Unique pixel values in the 40896.png mask are: [0]
# Unique pixel values in the 39532.png mask are: [0 3]
# Unique pixel values in the 40010.png mask are: [0 6 8]
# Unique pixel values in the 39741.png mask are: [0 4]
# Unique pixel values in the 55867.png mask are: [ 0 12]
# Unique pixel values in the 61035.png mask are: [0]
# Unique pixel values in the 69436.png mask are: [0 6]
# Unique pixel values in the 40106.png mask are: [ 0  4 12]
# Unique pixel values in the 69387.png mask are: [ 0  5 11]
# Unique pixel values in the 36384.png mask are: [0 2]
# Unique pixel values in the 40791.png mask are: [0 6]
# Unique pixel values in the 41078.png mask are: [0 2]
# Unique pixel values in the 45626.png mask are: [0 4]
# Unique pixel values in the 57601.png mask are: [ 0  9 12]
# Unique pixel values in the 45828.png mask are: [0 1 4 9]
# Unique pixel values in the 36236.png mask are: [0 1]
# Unique pixel values in the 69536.png mask are: [0 6]
# Unique pixel values in the 41173.png mask are: [0 3 4 6]
# Unique pixel values in the 69549.png mask are: [0 6 9]
# Unique pixel values in the 56753.png mask are: [ 0 10 11]
# Unique pixel values in the 41780.png mask are: [ 0  4  6  8 13]
# Unique pixel values in the 69873.png mask are: [0 3 8]
# Unique pixel values in the 36290.png mask are: [0 1]
# Unique pixel values in the 60922.png mask are: [ 0 12]
# Unique pixel values in the 45881.png mask are: [0 4]
# Unique pixel values in the 40372.png mask are: [ 0  4  6  8 12]
# Unique pixel values in the 46029.png mask are: [ 0  1  4  6  9 12]
# Unique pixel values in the 57895.png mask are: [0 4 6 9]
# Unique pixel values in the 41487.png mask are: [ 0 12]
# Unique pixel values in the 48997.png mask are: [0]
# Unique pixel values in the 59719.png mask are: [0]
# Unique pixel values in the 46927.png mask are: [0 4 6]
# Unique pixel values in the 40844.png mask are: [ 0 11 12]
# Unique pixel values in the 59707.png mask are: [0 1]
# Unique pixel values in the 39958.png mask are: [0 3 4]
# Unique pixel values in the 70504.png mask are: [0 6]
# Unique pixel values in the 41500.png mask are: [0 4 8]
# Unique pixel values in the 39433.png mask are: [0 1 4]
# Unique pixel values in the 45795.png mask are: [ 0  5 11]
# Unique pixel values in the 45722.png mask are: [0 1 4]
# Unique pixel values in the 45215.png mask are: [ 0  4  6 12]
# Unique pixel values in the 60234.png mask are: [ 0 12]
# Unique pixel values in the 69152.png mask are: [0]
# Unique pixel values in the 59435.png mask are: [ 0 11]
# Unique pixel values in the 61918.png mask are: [0 4 6]
# Unique pixel values in the 69888.png mask are: [0 3 6]
# Unique pixel values in the 40766.png mask are: [0 1 6]
# Unique pixel values in the 41085.png mask are: [0]
# Unique pixel values in the 45786.png mask are: [ 0  4  9 12 13]
# Unique pixel values in the 45293.png mask are: [0]
# Unique pixel values in the 46910.png mask are: [0]
# Unique pixel values in the 49009.png mask are: [ 0  8 12]
# Unique pixel values in the 60753.png mask are: [ 0  4  6  8  9 12]
# Unique pixel values in the 68884.png mask are: [0 9]
# Unique pixel values in the 40049.png mask are: [0 4]
# Unique pixel values in the 36231.png mask are: [0 2]
# Unique pixel values in the 41916.png mask are: [ 0  2 12]
# Unique pixel values in the 59606.png mask are: [0 3 4 6]
# Unique pixel values in the 69922.png mask are: [0 4]
# Unique pixel values in the 69492.png mask are: [0]
# Unique pixel values in the 61708.png mask are: [0 9]
# Unique pixel values in the 57528.png mask are: [0 6]
# Unique pixel values in the 59227.png mask are: [0 9]
# ...
# Unique pixel values in the 70486.png mask are: [0]
# Unique pixel values in the 69879.png mask are: [0]
# Unique pixel values in the 47013.png mask are: [ 0  9 11]
# Unique pixel values in the 59386.png mask are: [0 6]
# Unique pixel values in the 45662.png mask are: [ 0 12]
# Unique pixel values in the 45600.png mask are: [ 0 12]
# Unique pixel values in the 56746.png mask are: [0 6]
# Unique pixel values in the 36233.png mask are: [0]
# Unique pixel values in the 46360.png mask are: [0 6]
# Unique pixel values in the 47296.png mask are: [0 4]
# Unique pixel values in the 55933.png mask are: [0 4 6]
# Unique pixel values in the 57793.png mask are: [0 4 6]
# Unique pixel values in the 39950.png mask are: [0 8]
# Unique pixel values in the 39117.png mask are: [ 0  4 11 12]
# Unique pixel values in the 45761.png mask are: [0]
# Unique pixel values in the 48835.png mask are: [ 0  4  6 11]
# Unique pixel values in the 36265.png mask are: [0]
# Unique pixel values in the 56655.png mask are: [0 8]
# Unique pixel values in the 36234.png mask are: [0 1]
# Unique pixel values in the 69424.png mask are: [0 4 6]
# Unique pixel values in the 40788.png mask are: [0 1]
# Unique pixel values in the 41865.png mask are: [0 4 6]
# Unique pixel values in the 70406.png mask are: [0 4 6]
# Unique pixel values in the 41193.png mask are: [ 0 11]
# Unique pixel values in the 58713.png mask are: [0 4]
# Unique pixel values in the 60808.png mask are: [ 0  4 11]
# Unique pixel values in the 58857.png mask are: [0 2]
# Unique pixel values in the 40055.png mask are: [ 0 12]
# Unique pixel values in the 45981.png mask are: [0]
# Unique pixel values in the 67559.png mask are: [0 4]
# Unique pixel values in the 59539.png mask are: [0]
# Unique pixel values in the 67606.png mask are: [0 6]
# Unique pixel values in the 55928.png mask are: [0 4]
# Unique pixel values in the 44857.png mask are: [0 3]
# Unique pixel values in the 45889.png mask are: [0 4 6]
# Unique pixel values in the 40891.png mask are: [0]
# Unique pixel values in the 70360.png mask are: [0 6]
# Unique pixel values in the 62090.png mask are: [ 0  4 10 12]
# Unique pixel values in the 45493.png mask are: [0 6 9]
# Unique pixel values in the 39500.png mask are: [0]
# Unique pixel values in the 46611.png mask are: [ 0 12]
# Unique pixel values in the 56705.png mask are: [ 0  3 10 11 12]
# Unique pixel values in the 45230.png mask are: [ 0  1  4  6 11]
# Unique pixel values in the 62087.png mask are: [ 0  1 11]
# Unique pixel values in the 40019.png mask are: [0 9]
# Unique pixel values in the 41857.png mask are: [0]
# Unique pixel values in the 40009.png mask are: [ 0  3  4 12]
# Unique pixel values in the 45665.png mask are: [0]
# Unique pixel values in the 60777.png mask are: [0 1]
# Unique pixel values in the 57777.png mask are: [ 0  2 11]
# Unique pixel values in the 46042.png mask are: [0 4 6 9]
# Unique pixel values in the 60995.png mask are: [ 0  4 10]
# Unique pixel values in the 46652.png mask are: [ 0  4  6  9 12]
# Unique pixel values in the 55919.png mask are: [0 4 6]
# Unique pixel values in the 41491.png mask are: [0 4 6]
# Unique pixel values in the 58848.png mask are: [0 4 6]
# Unique pixel values in the 68947.png mask are: [0 4 9]
# Unique pixel values in the 41476.png mask are: [0 2 4 6]
# Unique pixel values in the 46984.png mask are: [0 3 4 6 9]
# Unique pixel values in the 40806.png mask are: [0 6]
# Unique pixel values in the 68961.png mask are: [0 8]
# Unique pixel values in the 57483.png mask are: [ 0  2  4  6 12 13]
# Unique pixel values in the 56590.png mask are: [0 4 9]
# Unique pixel values in the 46914.png mask are: [0]
# Unique pixel values in the 45847.png mask are: [ 0  1  9 11]
# Unique pixel values in the 69075.png mask are: [ 0 12]
# Unique pixel values in the 36311.png mask are: [0 8]
# Unique pixel values in the 46968.png mask are: [0 8]
# Unique pixel values in the 41171.png mask are: [ 0  3  4  6 12]
# Unique pixel values in the 60852.png mask are: [ 0 11]
# Unique pixel values in the 69386.png mask are: [0 2 3]
# Unique pixel values in the 69389.png mask are: [0]
# Unique pixel values in the 39071.png mask are: [0]
# Unique pixel values in the 40781.png mask are: [0]
# Unique pixel values in the 69411.png mask are: [ 0  6 13]
# Unique pixel values in the 58818.png mask are: [0 8]
# Unique pixel values in the 68982.png mask are: [0 4]
# Unique pixel values in the 57622.png mask are: [0 4 6]
# Unique pixel values in the 41944.png mask are: [0 1 9]
# Unique pixel values in the 57711.png mask are: [ 0  4  8  9 10 11 12]
# Unique pixel values in the 45757.png mask are: [0]
# Unique pixel values in the 45483.png mask are: [0]
# Unique pixel values in the 69924.png mask are: [0 2]
# Unique pixel values in the 36351.png mask are: [0 3 6 8]
# Unique pixel values in the 59296.png mask are: [ 0  6 12]
# Unique pixel values in the 46998.png mask are: [0 4]
# Unique pixel values in the 36294.png mask are: [ 0 13]
# Unique pixel values in the 70429.png mask are: [0 3]
# Unique pixel values in the 41459.png mask are: [0 3 4 6]
# Unique pixel values in the 69975.png mask are: [0 5 6]
# Unique pixel values in the 69173.png mask are: [ 0 10]
# Unique pixel values in the 36358.png mask are: [0 4 6]
# Unique pixel values in the 68908.png mask are: [0]
# Unique pixel values in the 69830.png mask are: [ 0  3 11 12]
# Unique pixel values in the 59289.png mask are: [0]
# Unique pixel values in the 46979.png mask are: [0 4 7]
# Unique pixel values in the 70364.png mask are: [0 8]
# Unique pixel values in the 40835.png mask are: [ 0 12]
# Unique pixel values in the 61707.png mask are: [ 0  8  9 12]
# Unique pixel values in the 45317.png mask are: [0 4 6]
# Unique pixel values in the 70058.png mask are: [0 9]
# Unique pixel values in the 45811.png mask are: [0 4 6]
# Unique pixel values in the 60251.png mask are: [ 0  6 11]
# Unique pixel values in the 45777.png mask are: [0 4 6]
# Unique pixel values in the 36310.png mask are: [0 4 6]
# Unique pixel values in the 36217.png mask are: [0]
# Unique pixel values in the 36269.png mask are: [ 0  4  6 11 13]
# Unique pixel values in the 45488.png mask are: [ 0  9 10]
# Unique pixel values in the 45927.png mask are: [0]
# Unique pixel values in the 59629.png mask are: [ 0 11]
# Unique pixel values in the 41087.png mask are: [0 4]
# Unique pixel values in the 69172.png mask are: [ 0 10]
# Unique pixel values in the 45921.png mask are: [0 6]
# Unique pixel values in the 55956.png mask are: [0 4]
# Unique pixel values in the 68943.png mask are: [ 0  6  9 13]
# Unique pixel values in the 70420.png mask are: [0]
# Unique pixel values in the 41836.png mask are: [0]
# Unique pixel values in the 46693.png mask are: [0 4 6]
# Unique pixel values in the 45635.png mask are: [0 1 6]
# Unique pixel values in the 45263.png mask are: [0 4]
# Unique pixel values in the 46940.png mask are: [ 0 12]
# Unique pixel values in the 69545.png mask are: [0 6]
# Unique pixel values in the 56642.png mask are: [ 0 10 11]
# Unique pixel values in the 70493.png mask are: [0 4 6]
# Unique pixel values in the 60997.png mask are: [ 0  7  9 12]
# Unique pixel values in the 57473.png mask are: [ 0  4  6 10 13]
# Unique pixel values in the 41112.png mask are: [0 3 8]
# Unique pixel values in the 39732.png mask are: [0 2]
# Unique pixel values in the 56819.png mask are: [0 4 6]
# Unique pixel values in the 56656.png mask are: [0 6 8]
# Unique pixel values in the 40860.png mask are: [0]
# Unique pixel values in the 56728.png mask are: [0 4 6]
# Unique pixel values in the 70927.png mask are: [ 0  6 12]
# Unique pixel values in the 70468.png mask are: [0]
# Unique pixel values in the 45809.png mask are: [0 4 7]
# Unique pixel values in the 48848.png mask are: [ 0  8 12]
# Unique pixel values in the 68958.png mask are: [ 0 10]
# Unique pixel values in the 45787.png mask are: [ 0  4  9 12 13]
# Unique pixel values in the 70015.png mask are: [0 6 9]
# Unique pixel values in the 60196.png mask are: [0 1 3 4 6]
# Unique pixel values in the 59361.png mask are: [0 6 9]
# Unique pixel values in the 70305.png mask are: [0 3 6]
# Unique pixel values in the 68955.png mask are: [ 0  6 10]
# Unique pixel values in the 45481.png mask are: [0 2]
# Unique pixel values in the 69923.png mask are: [0]
# Unique pixel values in the 58827.png mask are: [0]
# Unique pixel values in the 70010.png mask are: [0 3]
# Unique pixel values in the 39709.png mask are: [0 4 6]
# Unique pixel values in the 57945.png mask are: [ 0  1  6  9 12]
# Unique pixel values in the 45932.png mask are: [0 4 6]
# Unique pixel values in the 70931.png mask are: [0 5 6]
# Unique pixel values in the 40755.png mask are: [0]
# Unique pixel values in the 46039.png mask are: [0 4 6 9]
# Unique pixel values in the 60930.png mask are: [0 3 4 6]
# Unique pixel values in the 40846.png mask are: [0 3 9]
# Unique pixel values in the 45675.png mask are: [0 4 6]
# Unique pixel values in the 55871.png mask are: [0 8]
# Unique pixel values in the 45759.png mask are: [ 0 11]
# Unique pixel values in the 48941.png mask are: [0]
# Unique pixel values in the 67550.png mask are: [ 0  3  4 11]
# Unique pixel values in the 69007.png mask are: [0 5 6]
# Unique pixel values in the 45941.png mask are: [0]
# Unique pixel values in the 40868.png mask are: [0]
# Unique pixel values in the 40400.png mask are: [ 0  4  6 11]
# Unique pixel values in the 45241.png mask are: [0 4 6]
# Unique pixel values in the 45799.png mask are: [ 0  8 12]
# Unique pixel values in the 55922.png mask are: [0 4 6]
# Unique pixel values in the 41160.png mask are: [0]
# Unique pixel values in the 41792.png mask are: [0 4 8]
# Unique pixel values in the 36379.png mask are: [0 4 7]
# Unique pixel values in the 70441.png mask are: [ 0  5  7 10]
# Unique pixel values in the 39518.png mask are: [ 0  4 12]
# Unique pixel values in the 45669.png mask are: [0 4 6]
# Unique pixel values in the 45647.png mask are: [ 0  4  6 13]
# Unique pixel values in the 40404.png mask are: [ 0  4  6 11]
# Unique pixel values in the 46032.png mask are: [ 0  2  4  6  9 13]
# Unique pixel values in the 39941.png mask are: [0 4]
# Unique pixel values in the 69558.png mask are: [ 0  7 10]
# Unique pixel values in the 56800.png mask are: [ 0 11]
# Unique pixel values in the 45870.png mask are: [ 0  6 10 11]
# Unique pixel values in the 46344.png mask are: [ 0  4 12]
# Unique pixel values in the 60191.png mask are: [0 4 5]
# Unique pixel values in the 60734.png mask are: [ 0  1  4  6 11]
# Unique pixel values in the 45246.png mask are: [0 4 6]
# Unique pixel values in the 69416.png mask are: [0 6]
# Unique pixel values in the 45720.png mask are: [0 1 4]
# Unique pixel values in the 45640.png mask are: [ 0 11]
# Unique pixel values in the 59418.png mask are: [0 4 6]
# Unique pixel values in the 39416.png mask are: [ 0  9 11]
# Unique pixel values in the 41233.png mask are: [0 4 6 8]
# Unique pixel values in the 59677.png mask are: [ 0  3 11]
# Unique pixel values in the 41231.png mask are: [0 4 6 8]
# Unique pixel values in the 56016.png mask are: [0 2]
# Unique pixel values in the 41142.png mask are: [0]
# Unique pixel values in the 62030.png mask are: [0]
# Unique pixel values in the 69997.png mask are: [0 6]
# Unique pixel values in the 46592.png mask are: [0 3 4 6]
# Unique pixel values in the 60194.png mask are: [0 4 8]
# Unique pixel values in the 55916.png mask are: [ 0  6  8 13]
# Unique pixel values in the 59238.png mask are: [0 1]
# Unique pixel values in the 70283.png mask are: [0 4]
# Unique pixel values in the 45880.png mask are: [0 4]
# Unique pixel values in the 69562.png mask are: [0 5]
# Unique pixel values in the 40477.png mask are: [0 2]
# Unique pixel values in the 70466.png mask are: [0 6]
# Unique pixel values in the 39120.png mask are: [ 0  4  9 12]
# Unique pixel values in the 40107.png mask are: [0]
# Unique pixel values in the 41094.png mask are: [0 3]
# Unique pixel values in the 39789.png mask are: [ 0 12]
# Unique pixel values in the 45501.png mask are: [ 0 11]
# Unique pixel values in the 55989.png mask are: [ 0  6  7  8 12]
# Unique pixel values in the 45637.png mask are: [0 1 4 6]
# Unique pixel values in the 41480.png mask are: [0]
# Unique pixel values in the 55847.png mask are: [0 3 4]
# Unique pixel values in the 48975.png mask are: [ 0 12]
# Unique pixel values in the 41228.png mask are: [0 8]
# Unique pixel values in the 45724.png mask are: [0]
# Unique pixel values in the 56613.png mask are: [0]
# Unique pixel values in the 45526.png mask are: [0]
# Unique pixel values in the 58876.png mask are: [ 0  5 11]
# Unique pixel values in the 70387.png mask are: [0 3]
# Unique pixel values in the 56817.png mask are: [0 6]
# Unique pixel values in the 69174.png mask are: [0 5]
# Unique pixel values in the 40405.png mask are: [ 0 11 12]
# Unique pixel values in the 41781.png mask are: [0 4 6 8]
# Unique pixel values in the 70449.png mask are: [0 6 9]
# Unique pixel values in the 40454.png mask are: [0]
# Unique pixel values in the 62129.png mask are: [0 4 6]
# Unique pixel values in the 70041.png mask are: [0]
# Unique pixel values in the 47258.png mask are: [0]
# Unique pixel values in the 69057.png mask are: [0 2]
# Unique pixel values in the 69374.png mask are: [0 8]
# Unique pixel values in the 70343.png mask are: [0 6]
# Unique pixel values in the 61692.png mask are: [ 0  9 12]
# Unique pixel values in the 70285.png mask are: [0 1 6]
# Unique pixel values in the 40446.png mask are: [ 0 12]
# Unique pixel values in the 70352.png mask are: [0 3 4 6]
# Unique pixel values in the 41976.png mask are: [0 1]
# Unique pixel values in the 57900.png mask are: [0 4 6 9]
# Unique pixel values in the 59598.png mask are: [0 3 6]
# Unique pixel values in the 55888.png mask are: [0 2 6 7 8]
# Unique pixel values in the 59713.png mask are: [0 1 4 6]
# Unique pixel values in the 46385.png mask are: [0]
# Unique pixel values in the 45846.png mask are: [ 0  4  9 11]
# Unique pixel values in the 60895.png mask are: [0]
# Unique pixel values in the 47017.png mask are: [ 0  6  9 11]
# Unique pixel values in the 46969.png mask are: [0 6]
# Unique pixel values in the 46646.png mask are: [0 3 6 8]
# Unique pixel values in the 36278.png mask are: [0 4 6]
# Unique pixel values in the 67578.png mask are: [ 0  8 12]
# Unique pixel values in the 40893.png mask are: [0 1 8]
# Unique pixel values in the 70402.png mask are: [0 6]
# Unique pixel values in the 69496.png mask are: [0]
# Unique pixel values in the 45688.png mask are: [ 0  1  4  6 13]
# Unique pixel values in the 67594.png mask are: [0 4 6]
# Unique pixel values in the 45988.png mask are: [ 0  9 11 12]
# Unique pixel values in the 39472.png mask are: [0]
# Unique pixel values in the 45299.png mask are: [ 0  4  6 12]
# Unique pixel values in the 40784.png mask are: [0 6]
# Unique pixel values in the 45267.png mask are: [ 0 11]
# Unique pixel values in the 41758.png mask are: [0 4 6]
# Unique pixel values in the 45276.png mask are: [0 4 9]
# Unique pixel values in the 58851.png mask are: [ 0  4 12]
# Unique pixel values in the 45863.png mask are: [ 0  6 11]
# Unique pixel values in the 69160.png mask are: [ 0  8 12]
# Unique pixel values in the 45887.png mask are: [ 0  4  6 12 13]
# Unique pixel values in the 56645.png mask are: [ 0  3  4  8 12]
# Unique pixel values in the 40118.png mask are: [0]
# Unique pixel values in the 69054.png mask are: [0 3]
# Unique pixel values in the 45614.png mask are: [0]
# Unique pixel values in the 45612.png mask are: [0 1]
# Unique pixel values in the 45296.png mask are: [0 4]
# Unique pixel values in the 56020.png mask are: [0 2]
# Unique pixel values in the 39070.png mask are: [0 4]
# Unique pixel values in the 69471.png mask are: [0]
# Unique pixel values in the 47282.png mask are: [0 2]
# Unique pixel values in the 69589.png mask are: [0]
# Unique pixel values in the 46649.png mask are: [0 1]
# Unique pixel values in the 45807.png mask are: [0 4]
# Unique pixel values in the 39476.png mask are: [0]
# Unique pixel values in the 59258.png mask are: [0 4 6]
# Unique pixel values in the 45755.png mask are: [0]
# Unique pixel values in the 41100.png mask are: [0 7 8]
# Unique pixel values in the 46680.png mask are: [0 6]
# Unique pixel values in the 46669.png mask are: [0 4 6]
# Unique pixel values in the 41803.png mask are: [ 0  4 13]
# Unique pixel values in the 45599.png mask are: [ 0  8 12]
# Unique pixel values in the 55864.png mask are: [ 0 11]
# Unique pixel values in the 45684.png mask are: [0]
# All Masks created successfully
